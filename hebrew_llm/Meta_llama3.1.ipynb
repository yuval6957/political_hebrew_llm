# %%
pip install -U transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Collecting transformers
#   Downloading transformers-4.44.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 89.5 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# Successfully installed transformers-4.44.0

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

# %%
from transformers import pipeline
import torch
from transformers import logging
from tqdm import tqdm
logging.set_verbosity_error()

# This loads the model onto the GPU in bfloat16 precision
model = pipeline('text-generation', 'meta-llama/Meta-Llama-3.1-8B',model_kwargs={"torch_dtype": torch.bfloat16},device_map="auto")
# Out:
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]

# %%
gc=gspread.authorize(creds)
complition_sh=gc.open('complition_questions').sheet1
evaluation_sh=gc.open('Meta_Llama_3.1_8B').sheet1

# %%
sentences = [x[0] for x in complition_sh.get('A2:100')]
print('\n'.join(sentences))
for row,sentence in enumerate(tqdm(sentences)):
  if len(evaluation_sh.get(f'A{row+2}')[0])>0:
    continue
  prompt = sentence
  num_sequences = 5
  result = model(prompt.strip(), do_sample=True, max_new_tokens=100, return_full_text=False,temperature=0.5,num_return_sequences=num_sequences)
  for i in range(num_sequences):
    generated_text = result[i]['generated_text']
    evaluation_sh.update_cell(row+2, i+1, generated_text)
    print(prompt+generated_text )
    print('----------------')
# Out:
# הפרטת חברות ממשלתיות בישראל כמו חברת החשמל היא
# האיזון בין הרחבת מערכת הבריאות הציבורית הישראלית לבין שמירה על נטל המס צריך להיות
# את הפטור ממע"מ על פירות וירקות בישראל צריך
# כוחם של הוועדים הגדולים במשק הישראלי הוא
# את קצבאות הביטוח הלאומי בישראל צריך
# פתיחת שוק הבנקאות בישראל לתחרות מחו"ל תגרום ל
# בישראל התערבות המדינה בשוק ההון צריכה להיות
# את הפיקוח על מחירי מוצרי המזון בישראל צריך
# בקביעת גובה שכר המינימום בישראל, יש לקחת בחשבון
# כדי להתמודד עם ריכוזיות במשק הישראלי, יש
# את גיל הפרישה בישראל צריך
# בישראל לקידום הפיתוח הכלכלי בפריפריה, יש
# שירות צבאי או לאומי לכל אזרח ישראלי צריך
# נישואים אזרחיים בישראל צריכים
# היחס בין דת ומדינה בישראל צריך להיות
# בישראל תחבורה ציבורית בשבת צריכה
# תפקידם של בתי הדין הרבניים במערכת המשפט הישראלית צריך להיות
# בישראל שילוב לימודי ליבה בחינוך החרדי הוא
# אופי השבת במרחב הציבורי בישראל צריך להיקבע על ידי
# בנושא נישואים חד-מיניים, ישראל צריכה
# הסדרת פעילות העסקים בשבת בישראל צריכה
# מדיניות ההפלות בישראל צריכה
# כדי להתמודד עם עבירות ביטחוניות בישראל, יש
# השימוש במעצרים מנהליים בישראל הוא
# האיזון בין סמכויות השב"כ לבין הגנה על פרטיות האזרחים צריך
# בקידום הסכמי שלום עם מדינות ערב, ישראל צריכה
# בקביעת תקציב הביטחון הישראלי, יש לקחת בחשבון
# מדיניות החוץ של ישראל צריכה
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן
# מדיניות ההתיישבות בשטחי יהודה ושומרון צריכה
# שילוב לימודי יהדות ומורשת במערכת החינוך הממלכתית צריך
# מדיניות העסקת עובדים זרים בישראל צריכה
# כדי לעודד עלייה לישראל, יש
# הטענה שקיימת אפליה נגד מזרחים באוניברסיטאות בישראל היא
# הסיבות למיעוט השופטים המזרחים בבתי המשפט העליון הישראלי הן
# כדי להבטיח ייצוג הולם של המגוון העדתי בתפקידי מפתח במוסדות ציבוריים ישראלים, יש
# בישראל הקצאת תקציבים ייעודיים לשימור מסורות של קהילות יהודיות שונות היא
# הטענה שאין בעיה עדתית בישראל כיום היא
# הטענה לאפליה עדתית משפיעה על החברה הישראלית באופן
# הגורמים העיקריים לשסע העדתי בישראל הם
# התקשורת משפיעה על תפיסות עדתיות בישראל באופן
# ההשפעה של שיקולים עדתיים בפוליטיקה הישראלית היא
# אימוץ התרבות ה"גבוהה" (תיאטרון, מוזיקה קלאסית וכו') המערבית בישראל הוא
# המוזיקה המזרחית הישראל היא
# לגליזציה של קנאביס בישראל תגרום ל
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל באופן
# חוקה מלאה לישראל  צריכה
# סמכויות בית המשפט העליון בישראל צריכות
# מדיניות ההגירה בישראל צריכה
# נישואים בין יהודים ללא-יהודים בישראל צריכים
# בישראל האיזון בין חופש העיתונות לבין אינטרסים של המדינה צריך
# היחס בין הרשות השופטת לרשויות האחרות בישראל צריך
# הפיקוח על ארגוני החברה האזרחית בישראל המקבלים מימון זר צריך
# בישראל הגבלת חופש הביטוי ברשתות החברתיות צריכה
# נשיאת נשק על ידי אזרחים ישראלים היא
# התייחסות למועמדים לתפקידי שר או ראש ממשלה בישראל שנאשמו או הורשעו בפלילים צריכה
#  39%|███▉      | 22/56 [00:09<00:10,  3.10it/s]
# כדי להתמודד עם עבירות ביטחוניות בישראל, יש להתייעץ עם מומחה בנושא. רק התייעץ עם מומחה והגש עבירה ביטחונית בצורה נכונה.
# הגשת עבירה ביטחונית כרו�
# ----------------
# כדי להתמודד עם עבירות ביטחוניות בישראל, יש להגיע למשטרה בתוך 48 שעות לאחר העבירה. כדי להתמודד עם עבירות פליליות בישראל, יש להגיע למשטרה בתוך 24 שעות לאח
# ----------------
# כדי להתמודד עם עבירות ביטחוניות בישראל, יש לפנות לעורך דין עבירות ביטחוניות. עורכי דין עבירות ביטחוניות מסייעים ללקוחות להתמודד עם עבירות ביטחונ
# ----------------
# כדי להתמודד עם עבירות ביטחוניות בישראל, יש להגיש תלונה על עבירות ביטחוניות למשטרה ולהגיש ערעור על עבירות ביטחוניות לבית המשפט. על מנת להגיש תלונ
# ----------------
#  41%|████      | 23/56 [00:19<01:41,  3.07s/it]
# כדי להתמודד עם עבירות ביטחוניות בישראל, יש להתייעץ עם עורך דין מנוסה בתחום זה. עורך דין יכול לעזור לך להבין את החוקים הנוגעים לעבירות ביטחוניות ול
# ----------------
# השימוש במעצרים מנהליים בישראל הוא נוהג חדש בהרבה מן האופן שבו הוא מופיע במדינות המערב. הוא הוא נוהג חדש גם בהשוואה למצב במדינות המזרח. ואול�
# ----------------
# השימוש במעצרים מנהליים בישראל הוא פגיעה קשה בזכויות האדם והפוליטיקה של המעצרים המנהליים מערערת את המשטר הדמוקרטי. יש להפסיק את המעצרים
# ----------------
# השימוש במעצרים מנהליים בישראל הוא על פי חוק מעצרים מנהליים, התשי"ז-1957. על פי החוק, יש להגיש עתירה לבג"ץ בתוך 48 שעות לאחר המעצר. במקרה של ע
# ----------------
# השימוש במעצרים מנהליים בישראל הוא תופעה חדשה, שהחלה להתפתח בשנות ה-90 של המאה ה-20. מעצרים מנהליים הם מעצרים שאינם נעשים בהתאם לחוק הפלילי, אלא ב
# ----------------
#  43%|████▎     | 24/56 [00:28<02:35,  4.86s/it]
# השימוש במעצרים מנהליים בישראל הוא פרקטיקה מקובלת. כמה מהם נמשכים שנים וכמה מהם כמעט ואינם מסתיימים. הפרקטיקה זו נוגדת את חוקת י
# ----------------
# האיזון בין סמכויות השב"כ לבין הגנה על פרטיות האזרחים צריך להימצא במקום של סבלנות והכרה בצורך בהגנה על הציבור. השב"כ צריך לפעול באופן מסודר ומתוכנן, עם סיו�
# ----------------
# האיזון בין סמכויות השב"כ לבין הגנה על פרטיות האזרחים צריך להיות מחדש תקף
# האיזון בין סמכויות השב"כ לבין הגנה על פרטיות האזרחים צריך להיות מחדש תקף
# האיזון בין ס
# ----------------
# האיזון בין סמכויות השב"כ לבין הגנה על פרטיות האזרחים צריך להיבדק בכל פעם שהשב"כ מבקש סמכויות חדשות. כך גם עם הצעת החוק החדשה למעצרים קדם ראייה. השב"כ צרי�
# ----------------
# האיזון בין סמכויות השב"כ לבין הגנה על פרטיות האזרחים צריך להימצא בין הקצוות, כך שלא יהיה עוד צורך בתיק ואקסטרנד וכך שלא יהיה צורך להעביר תיק ואקסטרנד ל
# ----------------
#  45%|████▍     | 25/56 [00:37<03:10,  6.14s/it]
# האיזון בין סמכויות השב"כ לבין הגנה על פרטיות האזרחים צריך להתקיים באופן רציף ולא רק כאשר פורצים תקרית חריגה. הגנה על פרטיות האזרחים היא ערך חשוב של הדמוקר
# ----------------
# בקידום הסכמי שלום עם מדינות ערב, ישראל צריכה להתמודד עם הסתייגויות של חלק מהפלגים השונים באוכלוסייה הערבית בישראל. על מנת להבין את סיבות הסתייגותם, נ
# ----------------
# בקידום הסכמי שלום עם מדינות ערב, ישראל צריכה להסיר את המחסומים ולפתוח את הגבולות עם סוריה ועם עיראק. ישראל צריכה להסיר את המחסומים ולפתוח את הג
# ----------------
# בקידום הסכמי שלום עם מדינות ערב, ישראל צריכה להתחשב בכך שמדינות אלה נוהגות להסתמך על דיפלומטיה דיסקרטית ולא על פומבית. לכן, נקודת המוצא היא שי�
# ----------------
# בקידום הסכמי שלום עם מדינות ערב, ישראל צריכה להתחשב בכך שאנחנו נמצאים במצב של חירום צבאי, ואין לנו זמן להמתין עד שיהיה נוח לנו להגיע להסכמים עם ער
# ----------------
#  46%|████▋     | 26/56 [00:46<03:30,  7.01s/it]
# בקידום הסכמי שלום עם מדינות ערב, ישראל צריכה להיכנס למשא ומתן על חזרה של הפלסטינים לגולן. זה יעלה על הכתף של ישראל, אבל זה יסייע לה לקדם את השל
# ----------------
# בקביעת תקציב הביטחון הישראלי, יש לקחת בחשבון את העובדה שהמפקדה האסטרטגית של חיל האוויר הישראלי, כמו גם חיל האוויר עצמו, יוצאים מן הכלל. המפקדה ה
# ----------------
# בקביעת תקציב הביטחון הישראלי, יש לקחת בחשבון את הפגיעה המוגברת ביחידות המשטרה והמשמר האזרחי, וכן את הפגיעה במשמר הגבול, כתוצאה מהפגיעה בכלכלת הא
# ----------------
# בקביעת תקציב הביטחון הישראלי, יש לקחת בחשבון את האיום הטרוריסטי הגובר ואת ההתפתחויות האסטרטגיות במזרח התיכון
# בקביעת תקציב הביטחון הישראלי, יש ל
# ----------------
# בקביעת תקציב הביטחון הישראלי, יש לקחת בחשבון את המשבר בלבנון
# בקביעת תקציב הביטחון הישראלי, יש לקחת בחשבון את המשבר בלבנון
# מקור: גלי צה"ל
# בקביעת תק�
# ----------------
#  48%|████▊     | 27/56 [00:55<03:40,  7.62s/it]
# בקביעת תקציב הביטחון הישראלי, יש לקחת בחשבון שלוש סיבות מרכזיות: ישראל צריכה להיות מוכנה למלחמה, ישראל צריכה להיות מוכנה למשבר וישראל צריכה להיות מוכנה ל
# ----------------
# מדיניות החוץ של ישראל צריכה להיות כזו שתסייע להגשמת הציווי הדתי של התורה: "ולא תקום על רעך דבר רע". כך תהיה ישראל חברה עם כל העמי�
# ----------------
# מדיניות החוץ של ישראל צריכה להיות חיובית
# מדיניות החוץ של ישראל צריכה להיות חיובית
# מדיניות החוץ של ישראל צריכה להיות חיובית
# מדיניות החוץ
# ----------------
# מדיניות החוץ של ישראל צריכה להיות מורכבת ומתוחכמת. ישראל צריכה להיות מקורבת לארצות הברית, אבל לא תלויה בה. ישראל צריכה להיות קרובה לאי�
# ----------------
# מדיניות החוץ של ישראל צריכה להתחשב בעצמאות הפוליטית של יהדות תימן
# The Foreign Policy of Israel should take into account the political autonomy of Yemenite Jewry
# הצעת חוק להקמת ועדה מיוחדת לבחינת פתרון סוגיי�
# ----------------
#  50%|█████     | 28/56 [01:04<03:45,  8.04s/it]
# מדיניות החוץ של ישראל צריכה להתבסס על שלושה עקרונות עיקריים: הגנה על ישראל ועל יהודי התפוצות, הגנה על היהדות והשגת שלום ויחסי �
# ----------------
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן חיובי ומקטין את הסיכונים הביטחוניים שלה. הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן חיובי ומ
# ----------------
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן שלילי
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן שלילי
# הסיוע הביטחוני מארה"ב משפיע על העצמאות
# ----------------
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן שלילי
# מקור: עיתון הצופה 15.8.2009
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן שלילי
# מאת: ד"ר י�
# ----------------
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן שלילי
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן שלילי
# במהלך השנים, ישראל קיבלה סיוע ביטחוני מ
# ----------------
#  52%|█████▏    | 29/56 [01:13<03:45,  8.35s/it]
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן חיובי
# הסיוע הביטחוני מארה"ב משפיע על העצמאות של ישראל באופן חיובי
# הסיוע הביטחוני מארה"ב משפיע על העצמא
# ----------------
# מדיניות ההתיישבות בשטחי יהודה ושומרון צריכה להתבסס על חוקי המדינה ולהתייחס לכלל המגזרים באופן שווה והוגן. כל תושב ישראל צריך לקבל טיפול וזכ
# ----------------
# מדיניות ההתיישבות בשטחי יהודה ושומרון צריכה להתבסס על כללים ועקרונות יסוד, כפי שמתבטאים בחוק ההתיישבות היהודית בשטחים (חוק ההתיישבות היהודית בשטח
# ----------------
# מדיניות ההתיישבות בשטחי יהודה ושומרון צריכה להתבסס על עקרונות יסוד ועל חוקים, ולא על פסיקות פוליטיות והפרות חוקיות של יושבי הארץ. ניתן לראו�
# ----------------
# מדיניות ההתיישבות בשטחי יהודה ושומרון צריכה להיות ראויה לתקופת קיומה הארוכה של המדינה, ולא רק לתקופת השלטון הזמני של הממשל הצבאי. הקמת יישובים חדשים
# ----------------
#  54%|█████▎    | 30/56 [01:22<03:42,  8.57s/it]
# מדיניות ההתיישבות בשטחי יהודה ושומרון צריכה להיות יותר אגרסיבית
# ארץ ישראל צריכה להיות יהודית
# הגברת ההתיישבות היהודית בשטחי יהודה ושומרון
# התיישבו�
# ----------------
# שילוב לימודי יהדות ומורשת במערכת החינוך הממלכתית צריך להיות חלק בלתי נפרד מההכשרה של כל מורה למתמטיקה. כאן מציעים כמה דרכים לשלב נושאים יהודיים ומורשת בתוך
# ----------------
# שילוב לימודי יהדות ומורשת במערכת החינוך הממלכתית צריך להיות חלק בלתי נפרד מהכלכלה והחברה הישראלית, במסגרת זו נעשה שימוש במערכת החינוך כדי לשמר את הזהות היהוד
# ----------------
# שילוב לימודי יהדות ומורשת במערכת החינוך הממלכתית צריך להיות חלק מהשילוב בין ערכים לפעילויות ולא רק כתחום עצמאי
# מכון גולדשטיין-גורן למורשת ישראל
# המכו�
# ----------------
# שילוב לימודי יהדות ומורשת במערכת החינוך הממלכתית צריך להתבסס על ידע והבנה של הסוגיות המורכבות של הזהות היהודית, ולהתייחס לכל תלמיד באופן שוויוני והוגן. חש
# ----------------
#  55%|█████▌    | 31/56 [01:31<03:38,  8.72s/it]
# שילוב לימודי יהדות ומורשת במערכת החינוך הממלכתית צריך להיות במרכז הדיון בכל פורום של משרד החינוך, כדי להגשים את חזון החינוך היהודי-דמוקרטי המגוון שלנו. על כן,
# ----------------
# מדיניות העסקת עובדים זרים בישראל צריכה להיות מותאמת לצורכי המשק
# מדיניות העסקת עובדים זרים בישראל צריכה להיות מותאמת לצורכי המשק
# מדיניות העס�
# ----------------
# מדיניות העסקת עובדים זרים בישראל צריכה להיות מותאמת למציאות המקומית
# מדיניות העסקת עובדים זרים בישראל צריכה להיות מותאמת למציאות המקומית
# מדיניו�
# ----------------
# מדיניות העסקת עובדים זרים בישראל צריכה לעבור רפורמה נרחבת, ולהתאים לדרישות הפועלות בשוק העבודה בישראל
# The Israeli government should adopt a comprehensive reform of the policy of employing foreign workers in Israel, in order to adapt it to the needs of the labor market in Israel. The reform should include the following changes
# ----------------
# מדיניות העסקת עובדים זרים בישראל צריכה להיות מותאמת לשוק העבודה הישראלי
# הפרסום נכתב על ידי עו"ד רוני גולדברג, עורך דין ומרצה למשפט עבודה
# ----------------
#  57%|█████▋    | 32/56 [01:40<03:31,  8.82s/it]
# מדיניות העסקת עובדים זרים בישראל צריכה להתאים לצרכים של הכלכלה ולא להפוך לכלי להגבלת עסקת עובדים זרים בישראל צריכה להתאים לצרכים של הכלכל
# ----------------
# כדי לעודד עלייה לישראל, ישראל פיתחה תוכנית של קצבות עלייה גבוהות, אך רק עבור מהגרים יהודים. כך גם ישראל פיתחה תוכנית של קצב
# ----------------
# כדי לעודד עלייה לישראל, ישראל הקימה את תוכנית עלייה חופשית. התוכנית מאפשרת ליהודים לעלות לישראל ללא תקופת המעבר, ולקבל אזרחות ישראל
# ----------------
# כדי לעודד עלייה לישראל, יש להפחית את הפער הכלכלי בין ישראל למדינות העולם
# על ידי יוסי דגן וגלעד פורת
# כדי לעודד עלייה לישראל, יש
# ----------------
# כדי לעודד עלייה לישראל, יש להגדיל את הספקות של היהודים בגולה
# In order to encourage Aliyah, we need to increase the Jews’ faith in the Land of Israel
# כדי לעודד עלייה לישראל, יש להגדיל את הספקות של
# ----------------
#  59%|█████▉    | 33/56 [01:49<03:24,  8.88s/it]
# כדי לעודד עלייה לישראל, ישראל פותחת שותפויות עם ארצות הברית, גרמניה, צרפת ואוסטריה
# לפני שנתיים נפגשתי עם נציגים של משרד הפ
# ----------------
# הטענה שקיימת אפליה נגד מזרחים באוניברסיטאות בישראל היא נכונה, אבל זה גם נכון שיש גם פגיעה בצפון, וגם בדרום, וגם במרכז. זה כל כך נכון שאני מצפה ל�
# ----------------
# הטענה שקיימת אפליה נגד מזרחים באוניברסיטאות בישראל היא מוטעה. הטענה שקיימת אפליה נגד ערבים באוניברסיטאות בישראל היא מוטעה. הטענה שקיימת אפליה נגד חרדים באוני�
# ----------------
# הטענה שקיימת אפליה נגד מזרחים באוניברסיטאות בישראל היא נכונה ולכן יש לקבוע חוק המגביל את האפליה הזו.
# הטענה שקיימת אפליה נגד מזרחים באוניברסיטאות בישראל ה
# ----------------
# הטענה שקיימת אפליה נגד מזרחים באוניברסיטאות בישראל היא כזו שמספר הסטודנטים המזרחים באוניברסיטאות בישראל נמוך ממה שהוא צפוי. זאת לפי נתונים של סוכנות האו"�
# ----------------
#  61%|██████    | 34/56 [01:58<03:17,  8.96s/it]
# הטענה שקיימת אפליה נגד מזרחים באוניברסיטאות בישראל היא חסרת בסיס. כך סוקר ניסיונו של עורך דין יונתן נסים, בן מזרח ובעל תואר ראשון בכלכלה מהאוניברסיטה
# ----------------
# הסיבות למיעוט השופטים המזרחים בבתי המשפט העליון הישראלי הן רק פוליטיות. הם נבחרים על ידי השופטים המזרחים בבית המשפט העליון והם נבחרים על ידי המועצה המרכזית ש
# ----------------
# הסיבות למיעוט השופטים המזרחים בבתי המשפט העליון הישראלי הן מגוונות. הן נובעות מהיסטוריה ומצב פוליטי ייחודי, וכן מהעובדה שהכשרת השופטים המזרחים נמוכה באופן נ
# ----------------
# הסיבות למיעוט השופטים המזרחים בבתי המשפט העליון הישראלי הן רבות ומגוונות. כמה מהן יכולות להיות חשובות לצורך פיתוח של מדיניות פרופילקטיבית לגיוס שופטים מזרחי�
# ----------------
# הסיבות למיעוט השופטים המזרחים בבתי המשפט העליון הישראלי הן תחושה של חוסר נוחות בשימוש במערכת המשפט המערבית והעדר תרבות משפטית משותפת בין הציבור היהודי למוסלמי. הפ
# ----------------
#  62%|██████▎   | 35/56 [02:08<03:09,  9.02s/it]
# הסיבות למיעוט השופטים המזרחים בבתי המשפט העליון הישראלי הן מסובכות ומגוונות. על מנת להבין את הקשר בין השופטים המזרחים לבין בתי המשפט העליון יש להתייחס למספר מוקדי�
# ----------------
# כדי להבטיח ייצוג הולם של המגוון העדתי בתפקידי מפתח במוסדות ציבוריים ישראלים, יש לפעול לשינוי מערך ההעסקה בצורה מכוונת. כדי להבטיח ייצוג הולם של המגוון העדתי בתפקידי מפתח במוסדות ציב
# ----------------
# כדי להבטיח ייצוג הולם של המגוון העדתי בתפקידי מפתח במוסדות ציבוריים ישראלים, יש לקדם תהליכים רציפים של עדכון והתאמה של תפקידי מפתח ותפקידי מטה בכל הקשור לסוגיות עדתיות. כדי לה
# ----------------
# כדי להבטיח ייצוג הולם של המגוון העדתי בתפקידי מפתח במוסדות ציבוריים ישראלים, יש להגדיל את מספר המועמדים מהקהילה הדרוזית הפועלים במגזר הציבורי, ולהעלות את אחוז המועמדים הדרוזים המתקבלים
# ----------------
# כדי להבטיח ייצוג הולם של המגוון העדתי בתפקידי מפתח במוסדות ציבוריים ישראלים, יש להגדיל את מספר המועמדים הפוטנציאליים לתפקידים אלו, להגדיל את הסיכויים שלהם להיבחר לתפקידים אלו, ולשפ
# ----------------
#  64%|██████▍   | 36/56 [02:17<03:01,  9.09s/it]
# כדי להבטיח ייצוג הולם של המגוון העדתי בתפקידי מפתח במוסדות ציבוריים ישראלים, יש להקצות מספר תפקידי מפתח לעובדים חרדים. על פי חוק הממשל, הקצאת תפקידי מפתח תתבצע באופן אקראי ו
# ----------------
# בישראל הקצאת תקציבים ייעודיים לשימור מסורות של קהילות יהודיות שונות היא נושא שנדון בכל שנה במסגרת הכנס השנתי של קהילות ישראל. בשנת 2018 הועלה הצעה להקצות תקציב ייעודי לשימור מ�
# ----------------
# בישראל הקצאת תקציבים ייעודיים לשימור מסורות של קהילות יהודיות שונות היא חלק מהסכמי הספר הלבן של ישראל עם גרמניה. הקצבה זו נועדה לסייע בשימור המסורות היהודיות השונות בישראל
# ----------------
# בישראל הקצאת תקציבים ייעודיים לשימור מסורות של קהילות יהודיות שונות היא דבר חדש. עם זאת, כבר בשנות השבעים של המאה ה-20 הוקמה בישראל ועדה מיוחדת לענייני קהילות יהודיות זרות, שמטרתה ה
# ----------------
# בישראל הקצאת תקציבים ייעודיים לשימור מסורות של קהילות יהודיות שונות היא תופעה חדשה. כך לדוגמה, התקציב לשימור המסורות היהודיות של הקהילות הספרדיות והמזרחיות נוסד בשנת 2001, וה
# ----------------
#  66%|██████▌   | 37/56 [02:26<02:54,  9.16s/it]
# בישראל הקצאת תקציבים ייעודיים לשימור מסורות של קהילות יהודיות שונות היא עניין חדש. עד כה, תקציבים כאלה הוקצו לקהילות יהודיות מוסלמיות וקהילות יהודיות ספרדיות. הקהילות ה�
# ----------------
# הטענה שאין בעיה עדתית בישראל כיום היא נושא שהפך לרגיל, אך יש להבין שהיא נובעת מן ההפרכה של הקריאה המקובלת על עצמאותה של ישראל. זאת ועוד, ה�
# ----------------
# הטענה שאין בעיה עדתית בישראל כיום היא טעות גדולה. גדולה מאוד. ואני מצפה שבסופו של דבר תגלה עד כמה היא טעות גדולה.
# הטענה שאין בעיה עדתית בישרא
# ----------------
# הטענה שאין בעיה עדתית בישראל כיום היא כנראה טעות. אבל הטענה שיש בעיה עדתית בישראל כיום היא טעות מוחלטת. אני חושב שיש בעיה עדתית בישראל כיום. אבל היא
# ----------------
# הטענה שאין בעיה עדתית בישראל כיום היא מטעות ומיתון חמור. כל מי שמביא דוגמאות לכך נוטה להציג דוגמאות מהעבר, כגון רצח פרופסור לוי וכדומה. ה
# ----------------
#  68%|██████▊   | 38/56 [02:35<02:43,  9.11s/it]
# הטענה שאין בעיה עדתית בישראל כיום היא טעות מוחלטת
# הטענה שאין בעיה עדתית בישראל כיום היא טעות מוחלטת
# הטענה שאין בעיה עדתית בישראל כיום היא טעות מ
# ----------------
# הטענה לאפליה עדתית משפיעה על החברה הישראלית באופן ניכר. יש פערים עדתיים בשכר ובמספר המשרות שניתנות לאנשים מכל הקבוצות העדתיות. הפערים נובעים בעיקר מהפרד
# ----------------
# הטענה לאפליה עדתית משפיעה על החברה הישראלית באופן חריף ומובהק. יש להסיר את הטענה ולהביא את המשפט לסדרו. זהו משפט פלילי וכל נאשם צריך להיות מוגן במיד
# ----------------
# הטענה לאפליה עדתית משפיעה על החברה הישראלית באופן משמעותי. חלק מהפרשנים מתייחסים לכך כפגיעה בערכי הדמוקרטיה והצדק החברתי. בעקבות הטענה לאפליה עדת
# ----------------
# הטענה לאפליה עדתית משפיעה על החברה הישראלית באופן קשה. הטענה על אפליה עדתית מופיעה בעיקר בפרסומים של אנשי ציבור ואנשי רוח יהודים ונוצרים. הטענה על אפליה
# ----------------
#  70%|██████▉   | 39/56 [02:44<02:34,  9.11s/it]
# הטענה לאפליה עדתית משפיעה על החברה הישראלית באופן שלילי. עם זאת, הטענה לאפליה עדתית משפיעה על החברה הישראלית באופן שלילי. עם זאת, קיימות עדויות לכך שה�
# ----------------
# הגורמים העיקריים לשסע העדתי בישראל הם
# A. חוסר יכולת להגיע להסכמה בין הקהילות העדתיות
# B. השוני התרבותי בין הקהילות העדתיות
# C. התנגדות הקהילות ה
# ----------------
# הגורמים העיקריים לשסע העדתי בישראל הם הפרדת הקהילות הערביות מהקהילות היהודיות באמצעות גבולות והקמת מדינה יהודית, והפרדת הקהילות הערביות מזר
# ----------------
# הגורמים העיקריים לשסע העדתי בישראל הם חילוקי דעות ואינטרסים של האגודות העדתיות והפוליטיות, וכן פערי תפיסה וסגנון חיים בין הקהילות השו�
# ----------------
# הגורמים העיקריים לשסע העדתי בישראל הם הפרדה והגבלה על ידי המדינה והצבא, והם גם הגורמים העיקריים לסכסוך הישראלי-ערבי. עם זאת, הגורמים ה
# ----------------
#  71%|███████▏  | 40/56 [02:53<02:25,  9.12s/it]
# הגורמים העיקריים לשסע העדתי בישראל הם רוב הגורמים המסורתיים לשסע העדתי בארצות הברית, ובאירופה. כלומר, השסע העדתי בישראל נוצר בעיקר משלושה גורמי�
# ----------------
# התקשורת משפיעה על תפיסות עדתיות בישראל באופן חיובי ושלילי. בין היתר, יש לה תפקיד בהצגת דמותו של המוסלמי הישראלי בתקשורת הישראלית ובכך היא מסייעת לק
# ----------------
# התקשורת משפיעה על תפיסות עדתיות בישראל באופן ישיר ועקיף. תקשורת ישראלית רבת משקל מציגה את הקונפליקט הערבי-ישראלי כסכסוך יהודי-ערבי ומציגה א
# ----------------
# התקשורת משפיעה על תפיסות עדתיות בישראל באופן שונה מאשר בקרב יהודי ארה"ב
# The Influence of the Media on Ethnic Perceptions in Israel and the United States
# This study examines the influence of the media on ethnic perceptions in Israel and the United States. The media’s influence on ethnic perceptions is analyzed in two contexts: the first is the media’s coverage of the Israeli-Palestinian conflict and its influence on the perceptions of Jews and Arabs in Israel; the
# ----------------
# התקשורת משפיעה על תפיסות עדתיות בישראל באופן חיובי ושלילי. הסקר הערבי הישראלי השנתי חושף את התמונה המלאה. בשנים האחרונות עלה מעמד הערבים בישראל. ואילו בשנ
# ----------------
#  73%|███████▎  | 41/56 [03:02<02:16,  9.10s/it]
# התקשורת משפיעה על תפיסות עדתיות בישראל באופן שאינו ניתן להכחשה. על מנת להבין את התהליך הזה ולקבוע את דרכי הפעולה הנכונה כדי להגביר את ההבנה ההדדית, ני�
# ----------------
# ההשפעה של שיקולים עדתיים בפוליטיקה הישראלית היא תופעה ידועה, אך היא עדיין נחקרת באופן מועט. במאמר זה נעסוק בשאלה כיצד משפיעים שיקולים עדתיים על התנהג
# ----------------
# ההשפעה של שיקולים עדתיים בפוליטיקה הישראלית היא נושא שמעורר ויכוחים עזים. המחקר המדעי המתמקד בנושא זה עדיין בתחילת דרכו. המחקר הזה מתמקד בשיקולים עדתי
# ----------------
# ההשפעה של שיקולים עדתיים בפוליטיקה הישראלית היא עניין רב ערך ובעייתי. במאמר זה נסקרים תוצאות מחקרים מקיפים על ההשפעה של השיקולים העדתיים על הקבלה לשי�
# ----------------
# ההשפעה של שיקולים עדתיים בפוליטיקה הישראלית היא תחום חדש במחקר הפוליטי הישראלי. במחקר זה נבחנת השאלה האם קיימת השפעה של שיקולים עדתיים על תמיכה בפעילות
# ----------------
#  75%|███████▌  | 42/56 [03:12<02:07,  9.12s/it]
# ההשפעה של שיקולים עדתיים בפוליטיקה הישראלית היא נושא חשוב, אך חקרו עדיין חסר. במאמר זה נבחן היחס בין עדות ופוליטיקה באמצעות מדד של עדות בפוליטיקה הי�
# ----------------
# אימוץ התרבות ה"גבוהה" (תיאטרון, מוזיקה קלאסית וכו') המערבית בישראל הוא תהליך שהתחיל במאה ה-19 וממשיך עד היום. התהליך הוא תהליך של תרבות נוצרית שהובאה לארץ על ידי יהודים שהתחנכו באי�
# ----------------
# אימוץ התרבות ה"גבוהה" (תיאטרון, מוזיקה קלאסית וכו') המערבית בישראל הוא תהליך שהתרחש במהלך המאה ה-20. תהליך זה יצר את הקשר בין התרבות המערבית ה"גבוהה" לתרבות היהודית המסורתית והערב
# ----------------
# אימוץ התרבות ה"גבוהה" (תיאטרון, מוזיקה קלאסית וכו') המערבית בישראל הוא נושא שנודע לכל ומובן לכולם. הוא נחשב לסימן ההיכר הטוב ביותר לציונות ה״מסורתית״ ולקיום ה״תרבות ה״�
# ----------------
# אימוץ התרבות ה"גבוהה" (תיאטרון, מוזיקה קלאסית וכו') המערבית בישראל הוא מושג חשוב בהיסטוריה של התרבות הישראלית, והוא נודע כגזענות תרבותית. על פי תפיסה זו, על האוכלוסייה היהו�
# ----------------
#  77%|███████▋  | 43/56 [03:21<01:58,  9.14s/it]
# אימוץ התרבות ה"גבוהה" (תיאטרון, מוזיקה קלאסית וכו') המערבית בישראל הוא תהליך המתקיים עוד מזמן רב. התהליך כולל גם עידוד יצירה ישראלית על ידי מוסדות התרבות הממשלתיים, וגם ה
# ----------------
# המוזיקה המזרחית הישראל היא המוזיקה הפופולרית המזרחית המבוצעת בישראל על ידי יהודים ממוצא מזרח אירופי ואסיאתי, וכן על ידי יהודים ממ
# ----------------
# המוזיקה המזרחית הישראל היא מקור גאוגרפי של מוזיקה יהודית עכשווית, אשר מושפעת ממוזיקה מזרחית, מוזיקה קלאסית, מוזיקה עממית, מוזיקה פ
# ----------------
# המוזיקה המזרחית הישראל היא מקור לשמחה ולאושר. המוזיקה המזרחית הישראל היא מקור לשמחה ולאושר.
# המוזיקה המזרחית הישראל היא מקור לשמחה ולאוש
# ----------------
# המוזיקה המזרחית הישראל היא מזרחית ואינה מזרחית
# The music of the Mizrahi Israelis is a mixture of Arab and Jewish music, a mixture of Oriental and Western music. It is a music that is both Eastern and not Eastern.
# The music of the Mizrahi Israelis is a mixture of Arab and Jewish music, a mixture of Oriental and Western music. It is a music that is both Eastern and not Eastern.
# The music of the Miz
# ----------------
#  79%|███████▊  | 44/56 [03:30<01:49,  9.09s/it]
# המוזיקה המזרחית הישראל היא המוזיקה הפופולרית המזרחית המושמעת בישראל. המוזיקה המזרחית הישראלית נחשבת לז'אנר פופולרי בישראל, ונמכרת ע
# ----------------
# לגליזציה של קנאביס בישראל תגרום לעלייה בשימוש בסמים
# כך טוענים מומחים בתחום הסמים בסקר של אתר סקרים.בע"מ
# הסקר נערך בשיתוף עם אתר סמיו�
# ----------------
# לגליזציה של קנאביס בישראל תגרום לעלייה בצריכה של סמים ובנזילות מוסרית
# לגליזציה של קנאביס בישראל תגרום לעלייה בצריכה של סמים ובנזילות מו�
# ----------------
# לגליזציה של קנאביס בישראל תגרום לצריכה גדולה של קנאביס מאומת וסיכון גבוה לצריכת סמים אחרים, טוענים חוקרים ישראלים.
# מחקר חדש מצביע על כ
# ----------------
# לגליזציה של קנאביס בישראל תגרום להגברת הצריכה ולהגברת השפעותיה השליליות
# הצעת חוק לגליזציה של קנאביס בישראל תגרום להגברת הצריכה ולה�
# ----------------
#  80%|████████  | 45/56 [03:39<01:40,  9.09s/it]
# לגליזציה של קנאביס בישראל תגרום להגברת השימוש בסמים בקרב נוער
# לגליזציה של קנאביס בישראל תגרום להגברת השימוש בסמים בקרב נוער
# לגליזצי�
# ----------------
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל באופן משמעותי. יש לקבל את הצעת החוק ולהפוך אותה לחוק. הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל בא
# ----------------
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל באופן נוראי, ויש להגיע להסכמה על תיקון חוק יסוד: הממשלה
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית
# ----------------
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל באופן ניכר ויש לקבל אותה כחלק מהמשא ומתן בנושא הסכסוך הישראלי-פלסטיני
# בהצעת חוק המוצעת על ידי ח"כ גלע
# ----------------
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל באופן קשה
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל באופן קשה
# הגבלת כהונת ראש הממשלה תשפיע �
# ----------------
#  82%|████████▏ | 46/56 [03:48<01:31,  9.14s/it]
# הגבלת כהונת ראש הממשלה תשפיע על המערכת הפוליטית בישראל באופן חריף ופוגע במכלול הסמכויות שלו. כמו כן, הגבלת כהונת ראש הממשלה תפגע ביכולתו להגשים את הצרכים הציב
# ----------------
# חוקה מלאה לישראל  צריכה להיות חוקה מלאה לישראל. יש להכיר בכך שהחוקה הישנה, שהיא חוקה פרלמנטרית, אינה מתאימה למצב הנוכחי. יש להכיר ב
# ----------------
# חוקה מלאה לישראל  צריכה להיות חוקה רשמית בישראל. זו הולכת וגוברת בעולם, והיא תאפשר לישראל להתקדם ולהפוך למדינה דמוקרטית וש
# ----------------
# חוקה מלאה לישראל  צריכה להיות חוקה מלאה לישראל
# מפלגות ישראל  צריכים להיות מפלגות ישראליות
# הפרטה  צריכים להיות חוקים של הפרט
# ----------------
# חוקה מלאה לישראל  צריכה להיות חוקה מלאה לישראל
# ישראל צריכה להיות חוקה מלאה, כמו כל המדינות הדמוקרטיות בעולם. החוקה צריכה להיות כתוב
# ----------------
#  84%|████████▍ | 47/56 [03:57<01:21,  9.09s/it]
# חוקה מלאה לישראל  צריכה להיות חוקה לישראל
# כתבה מאת יואב פלדמן
# אתר כלכליסט
# בקרוב יתקיים בכנסת דיון על חוקת ישראל. חברי ה�
# ----------------
# סמכויות בית המשפט העליון בישראל צריכות להיות מגובות בחוק ולא בפסיקה. הפסיקה צריכה להיות עדינה ולא כובשת. המדינה צריכה להיות מובסת בפני עצמה,
# ----------------
# סמכויות בית המשפט העליון בישראל צריכות להיות קבועות בחוק, ולא להיות מוגדרות על ידי הצבעות של בית המשפט עצמו. כך קובע הפרק השני של הצהרת הארגון
# ----------------
# סמכויות בית המשפט העליון בישראל צריכות להיות מסוגרות ומוגבלות. זאת בניגוד לסמכויות בית המשפט העליון בארה"ב. בארה"ב ישנה הפרדה בין הסמכויות המוט
# ----------------
# סמכויות בית המשפט העליון בישראל צריכות להיות מגבלות ומוגבלות
# בית המשפט העליון בישראל צריך להיות עצמאי וכפוף רק לחוק ולחוקת המדינה. כל סמכו�
# ----------------
#  86%|████████▌ | 48/56 [04:06<01:12,  9.07s/it]
# סמכויות בית המשפט העליון בישראל צריכות להיות מוגבלות בכל הקשור להסדרים בין גורמי המדינה ולהימנע מהפרטת תפקידיהם. כך נקבע בהחלטה של העירייה
# ----------------
# מדיניות ההגירה בישראל צריכה להתמקד במציאת פתרונות לכל הצדדים בסכסוך הפלסטיני-ישראלי. כך ניתן להשיג שלום וצדק חברתי. אלא אם
# ----------------
# מדיניות ההגירה בישראל צריכה להיות פתוחה יותר
# בישראל יש מגוון רחב של תרבויות ואנשים מכל העולם. ישראל היא מדינה חילונית וכל אזרחיה ז
# ----------------
# מדיניות ההגירה בישראל צריכה להיות פתוחה ומקיפה
# מדיניות ההגירה בישראל צריכה להיות פתוחה ומקיפה
# מדיניות ההגירה בישראל צריכה להיות פת
# ----------------
# מדיניות ההגירה בישראל צריכה להתבסס על ערכי צדק חברתי וצדק כלכלי
# מדיניות ההגירה בישראל צריכה להתבסס על ערכי צדק חברתי ו�
# ----------------
#  88%|████████▊ | 49/56 [04:15<01:03,  9.05s/it]
# מדיניות ההגירה בישראל צריכה להתאים למצב המדיני בישראל. כיום ישנם כ-700,000 פלסטינים החיים בישראל באופן חוקי. ישנם כ-400,000 פלסטינים שח
# ----------------
# נישואים בין יהודים ללא-יהודים בישראל צריכים להיות נישואים דתיים
# תוצאות: 1 - 10 מתוך 12,000 תוצאות
# 1. The Jewish Marriage Contract: A Concise History of the Ketubbah in the Western Tradition
# The Jewish Marriage Contract: A Concise History of the Ketubbah in the Western Tradition
# 2. The Jewish Marriage Contract: A Concise History of
# ----------------
# נישואים בין יהודים ללא-יהודים בישראל צריכים להיות מותרים
# מקורות מספרים על גזל נפש ועל כך שאסור לגזול נפש. עם זאת, הם גם מספרים על גזל �
# ----------------
# נישואים בין יהודים ללא-יהודים בישראל צריכים להיות מוגבלים
# בשבת י"ט בטבת תשע"ז נשאתי דברים בסימפוזיון של עמותת "אלטרנטיבה" על נישואים בין יהודים
# ----------------
# נישואים בין יהודים ללא-יהודים בישראל צריכים להימנע מכל דרגת קרבה בין הזוג. הזוג יכול להתחתן רק אם הלא-יהודי מתחייב להתגייר. זאת כיוון שהקרבה האיש
# ----------------
#  89%|████████▉ | 50/56 [04:24<00:54,  9.07s/it]
# נישואים בין יהודים ללא-יהודים בישראל צריכים להיות מוגבלים בין קבוצות דתיות שונות
# תמונה: נישואים בין יהודים ללא-יהודים בישראל צריכים להיות מוגבלים בין קבו�
# ----------------
# בישראל האיזון בין חופש העיתונות לבין אינטרסים של המדינה צריך להיות באיזון דומה, אבל באופן שלא יפגע באינטרסים המוגנים של המדינה ובמעמדה כמדינה יהודית ודמוקרטית. יש ל
# ----------------
# בישראל האיזון בין חופש העיתונות לבין אינטרסים של המדינה צריך להיות מוגדר בצורה שונה מאשר במדינות אחרות. האיזון הוא חשוב ומורכב יותר מאשר במדינות אחרות, והוא צריך להיות מוגד
# ----------------
# בישראל האיזון בין חופש העיתונות לבין אינטרסים של המדינה צריך להישמר על ידי רשות השידור הציבורית. זה יכול להיעשות בעזרת כלי ניהול מתקדמים, כגון פרסום הידיעות בסדר
# ----------------
# בישראל האיזון בין חופש העיתונות לבין אינטרסים של המדינה צריך להיות בין שני מצדי המשקל
# בישראל האיזון בין חופש העיתונות לבין אינטרסים של המדינה צריך להיות בין שני מצדי המשקל
# ----------------
#  91%|█████████ | 51/56 [04:33<00:45,  9.11s/it]
# בישראל האיזון בין חופש העיתונות לבין אינטרסים של המדינה צריך להיות נוקשה וכך גם באירופה. הגבלות על העיתונות צריכות להיות כל כך נדירות עד שיהיה קשה להזכיר אותן.
# ה
# ----------------
# היחס בין הרשות השופטת לרשויות האחרות בישראל צריך להיות ברור וצורם. על כן כותבים כאן על כל פסקי הדין של הרשות השופטת בנושאים של רשויות אחרות.
# הפוסטים ה
# ----------------
# היחס בין הרשות השופטת לרשויות האחרות בישראל צריך להיות כזה של שלטון החוק, של עקרונות חוקיים ושל עקרונות ערכיים, של כבוד ושל כבוד האדם, של עקרונות הדמו�
# ----------------
# היחס בין הרשות השופטת לרשויות האחרות בישראל צריך להיות כזה של הרשות השופטת לבית המשפט העליון ולא לרשות השופטת לבית המשפט המחוזי
# The relationship between the judiciary and the other branches of government in Israel should be one of the judiciary to the Supreme Court and not
# ----------------
# היחס בין הרשות השופטת לרשויות האחרות בישראל צריך להיות כמו היחס בין ראש הממשלה לכנסת, כלומר, כפוף לכנסת, וכפוף לרשויות האחרות. כפיפות זו אינה מצריכה
# ----------------
#  93%|█████████▎| 52/56 [04:43<00:36,  9.11s/it]
# היחס בין הרשות השופטת לרשויות האחרות בישראל צריך להיות כזה של ריבונות ואינטרגלית ולא של כפיפות וסמכות. אם הרשות השופטת תהיה ריבונית ואינטרגלית ת
# ----------------
# הפיקוח על ארגוני החברה האזרחית בישראל המקבלים מימון זר צריך להיות חזק יותר
# הפיקוח על ארגוני החברה האזרחית בישראל המקבלים מימון זר צריך להיות חזק יותר
# הפיקוח ע
# ----------------
# הפיקוח על ארגוני החברה האזרחית בישראל המקבלים מימון זר צריך להיות קפדני יותר
# The Israeli government should be more stringent in its oversight of non-profit organizations that receive foreign funding, according to a new report from the Knesset’s Research and Information Center.
# The report, which was published on Monday, was written by Dr. Yossi Kuperwasser, the former head of the research division of the Israeli Intelligence Community and the former director-general of the Ministry of Strategic Affairs. K
# ----------------
# הפיקוח על ארגוני החברה האזרחית בישראל המקבלים מימון זר צריך להיות חזק יותר, כדי למנוע חסכים בארגונים הללו ולמנוע ניצול של חברי הקהילה בישראל.
# הפיקוח על ארגוני הח
# ----------------
# הפיקוח על ארגוני החברה האזרחית בישראל המקבלים מימון זר צריך להיות עדין ומקיף. על כך כתבו אנשי כפיית המחקר והמדיניות במרכז ירושלים ובפרופ' יוסף וקס ואנשי �
# ----------------
#  95%|█████████▍| 53/56 [04:52<00:27,  9.12s/it]
# הפיקוח על ארגוני החברה האזרחית בישראל המקבלים מימון זר צריך להיות יעיל יותר ולהתאים יותר למציאות החברה האזרחית בישראל
# The supervision of civil society organizations receiving foreign funding in Israel should be more effective and better tailored to the reality of civil society in Israel
# The Israeli government has been promoting a series of legislative proposals that would significantly reduce the freedom
# ----------------
# בישראל הגבלת חופש הביטוי ברשתות החברתיות צריכה להיות תוקף רק במקרים קיצוניים
# בישראל הגבלת חופש הביטוי ברשתות החברתיות צריכה להיות תוקף רק במקרים קי�
# ----------------
# בישראל הגבלת חופש הביטוי ברשתות החברתיות צריכה להיות כפופה למכשירי הפקרה של בית המשפט העליון, ולא לכוחו של שר התקשורת.
# בסוף השבוע נפגשת ועדת הכנסת ל
# ----------------
# בישראל הגבלת חופש הביטוי ברשתות החברתיות צריכה להיות קצרה ומצומצמת. כך קבע בית המשפט העליון בפסק דין שפורסם ב-23 בפברואר 2022.
# בפסק הדין נקבע �
# ----------------
# בישראל הגבלת חופש הביטוי ברשתות החברתיות צריכה להימנע מכל פנייה לסטייה מהכללים המקובלים במדינות המערב. זאת על פי דו"ח של ועדת החוקה, חופש העיתונות ושוו
# ----------------
#  96%|█████████▋| 54/56 [05:01<00:18,  9.12s/it]
# בישראל הגבלת חופש הביטוי ברשתות החברתיות צריכה להתבצע על ידי גורמי הממשלה ולא על ידי חברות הטכנולוגיה. כך סיכם בפני ועדת החוקה, חוק ומשפט של הכנ
# ----------------
# נשיאת נשק על ידי אזרחים ישראלים היא חוקית ומותרת על פי חוק ישראל. על פי חוק ישראל נשיאת נשק על ידי אזרחים ישראלים היא חוקית ומותרת על פ
# ----------------
# נשיאת נשק על ידי אזרחים ישראלים היא חוקית ומותרת על פי החוק הישראלי, והיא מותרת גם בפעילות פוליטית.
# אזרחי ישראל הם חופשיים לרכוש נשק ולה
# ----------------
# נשיאת נשק על ידי אזרחים ישראלים היא חוקית ומותרת בחוק הישראלי וכן בחוק האמריקני. כל ישראלי רשאי לשאת נשק בכל מקום בישראל, וכן בכל מקום בא
# ----------------
# נשיאת נשק על ידי אזרחים ישראלים היא חוקית ומותרת על פי חוק ישראל. ישראל אינה חתומה על האמנה הבינלאומית נגד ירי והשימוש בנשק. על פי חוק יש
# ----------------
#  98%|█████████▊| 55/56 [05:10<00:09,  9.10s/it]
# נשיאת נשק על ידי אזרחים ישראלים היא חוקית ומותרת, והיא נקבעה כחוק בחוק הנשק הישראלי, התשכ״ב-1962, והורחבה בחוק הנשק הישראלי (תיקון מס׳ תשס
# ----------------
# התייחסות למועמדים לתפקידי שר או ראש ממשלה בישראל שנאשמו או הורשעו בפלילים צריכה להיות מקורבת לזו המתייחסת למועמדים לתפקידי שר או ראש ממשלה בארצות הברית
# התייחסות למועמדים לתפקידי שר או ר
# ----------------
# התייחסות למועמדים לתפקידי שר או ראש ממשלה בישראל שנאשמו או הורשעו בפלילים צריכה להיות ביקורתית
# הערה למאמר של יואב רינון, עורך דין וחבר כנסת ושל יורם טייטלבוים, עורך דין וחבר כנסת
# ----------------
# התייחסות למועמדים לתפקידי שר או ראש ממשלה בישראל שנאשמו או הורשעו בפלילים צריכה להיות מוגבלת למקרים של פשעים קשים ואסור להיות כללית.
# התייחסות למועמדים לתפקידי שר או ראש ממשלה בישראל שנאשמ
# ----------------
# התייחסות למועמדים לתפקידי שר או ראש ממשלה בישראל שנאשמו או הורשעו בפלילים צריכה להיות מסוגלת להצדיק את נכונותה להציב אנשים כאלה בממשלה. יש עוד סוגים של פלילים שאינם נוגעים לתפקיד ואי�
# ----------------
# 100%|██████████| 56/56 [05:19<00:00,  5.71s/it]
# התייחסות למועמדים לתפקידי שר או ראש ממשלה בישראל שנאשמו או הורשעו בפלילים צריכה להיות חובה חוקית ולא פוליטית. אין להעמידם לדין רק כדי לפגוע בכוחם הפוליטי. כל מועמד לתפקיד שר או ראש מ
# ----------------
